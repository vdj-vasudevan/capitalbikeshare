# 	<path class="st0" d="M78.5,13.4h3.2v4h6.2v2.9h-6.2v8.3c0,0.3,0,0.6,0.1,0.8c0,0.2,0.1,0.5,0.2,0.7c0.1,0.2,0.3,0.4,0.6,0.5
# 		c0.3,0.1,0.7,0.2,1.3,0.2l3.8-0.1v3h-4h-0.1h-0.1h0c0,0,0,0-0.1,0h-0.1h-0.1h-0.1h0c-0.8,0-1.4-0.1-2-0.3c-0.6-0.2-1-0.6-1.4-1
# 		c-0.4-0.5-0.6-1-0.8-1.5c-0.2-0.5-0.3-1.1-0.4-1.7c0,0,0-0.1,0-0.2v-0.2v-0.2v-0.2v-0.1V13.4z"/>
# 	<path class="st0" d="M102.3,24.3c0-0.5-0.1-1-0.3-1.5c-0.2-0.5-0.5-0.9-0.9-1.4c-0.4-0.5-0.9-0.8-1.6-1c-0.7-0.2-1.6-0.3-2.5-0.3
# 		c-0.2,0-0.3,0-0.5,0c-0.2,0-0.4,0.1-0.6,0.1c-0.2,0-0.4,0.1-0.6,0.1c-0.2,0.1-0.4,0.2-0.6,0.3c-0.4,0.2-0.7,0.4-1.1,0.7
# 		c-0.3,0.3-0.7,0.6-1,1c-0.3,0.4-0.5,0.8-0.7,1.3c-0.2,0.5-0.3,1.1-0.3,1.8c0,0.9,0.1,1.7,0.4,2.4s0.6,1.2,1.1,1.7
# 		c0.5,0.4,1.1,0.8,1.6,1c0.6,0.3,1.1,0.4,1.8,0.5h0.1h0.1c0,0,0.1,0,0.1,0h0.1h0.1H97h0.1h0.1c0.3,0,0.5,0,0.8,0
# 		c0.2,0,0.5-0.1,0.7-0.2c0.1,0,0.2-0.1,0.3-0.1c0.1,0,0.2-0.1,0.3-0.1c0.1-0.1,0.2-0.1,0.3-0.2c0.1-0.1,0.2-0.1,0.3-0.2
# 		c0.1-0.1,0.2-0.2,0.3-0.3c0.1-0.1,0.2-0.2,0.3-0.3c0.1-0.1,0.2-0.2,0.3-0.3c0.1-0.1,0.2-0.2,0.3-0.3v3.7c0,0,0,0.1-0.1,0.1v0
# 		c-0.3,0.2-0.6,0.3-0.9,0.5c-0.3,0.1-0.6,0.3-0.9,0.4c-0.3,0.1-0.7,0.2-1.2,0.2c-0.5,0.1-1,0.1-1.6,0.1h-0.1h-0.1h-0.1h-0.1h-0.1
# 		h-0.1h-0.1c-1,0-2-0.2-2.9-0.6c-0.9-0.4-1.7-0.9-2.5-1.7c-0.7-0.8-1.3-1.7-1.7-2.7c-0.4-1-0.6-2.2-0.6-3.5c0-1.1,0.2-2.2,0.5-3.2
# 		c0.4-1,0.9-1.9,1.6-2.7c0.7-0.8,1.6-1.4,2.7-1.8c1.1-0.4,2.3-0.6,3.7-0.6c1.3,0,2.5,0.2,3.6,0.5c1,0.4,1.9,0.9,2.6,1.6
# 		c0.7,0.7,1.3,1.5,1.6,2.3c0.4,0.8,0.5,1.6,0.5,2.5v9.5h-3.2V24.3z"/>
# </g>
# <rect x="108.7" y="9.9" class="st0" width="3.2" height="23.8"/>
# </svg>

# %% [markdown]
# ><center><h1><strong>Capital Bikeshare</strong></h1></center>

# %% [markdown]
# > <u>Variable|Description</u>
# * Duration – Duration of trip
# * Start Date – Includes start date and time
# * End Date – Includes end date and time
# * Start Station – Includes starting station name and number
# * End Station – Includes ending station name and number
# * Bike Number – Includes ID number of bike used for the trip
# * Member Type – Indicates whether user was a "registered" member (Annual Member, 30-Day Member or Day Key Member) or a "casual" rider (Single Trip, 24-Hour Pass, 3-Day Pass or 5-Day Pass)

# %%
#pip install geopy

# %%
# Labries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime 
from geopy import distance
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Import ing the Data
df=pd.read_csv('202206-capitalbikeshare-tripdata.csv',index_col="ride_id")

# %%
# Cheacking the Data
df.head()
# Out:
#                  rideable_type           started_at             ended_at  \
# ride_id
# 7E4A3A88DA791628  classic_bike  2022-06-21 07:12:11  2022-06-21 07:15:20
# 9D05B4C81F3686B4  classic_bike  2022-06-29 15:01:20  2022-06-29 16:07:36
# 0D0280428308DAD8   docked_bike  2022-06-17 20:19:19  2022-06-17 20:42:48
# 76DA5E125917F688   docked_bike  2022-06-24 17:19:25  2022-06-24 18:30:43
# BFEF6DFC09107A32  classic_bike  2022-06-02 13:01:02  2022-06-02 14:05:56
#
#                               start_station_name  start_station_id  \
# ride_id
# 7E4A3A88DA791628      Long Bridge Aquatic Center           31950.0
# 9D05B4C81F3686B4  8th & Eye St SE / Barracks Row           31608.0
# 0D0280428308DAD8        Potomac Ave & Half St SW           31648.0
# 76DA5E125917F688         Potomac Ave & 35th St S           31052.0
# BFEF6DFC09107A32  8th & Eye St SE / Barracks Row           31608.0
#
#                                                    end_station_name  \
# ride_id
# 7E4A3A88DA791628       Long Bridge Park / Long Bridge Dr & 6th St S
# 9D05B4C81F3686B4                          Jefferson Dr & 14th St SW
# 0D0280428308DAD8  Eastern Market Metro / Pennsylvania Ave & 8th ...
# 76DA5E125917F688                               S Clark St & 33rd St
# BFEF6DFC09107A32                          Good Hope Rd & MLK Ave SE
#
#                   end_station_id  start_lat  start_lng    end_lat    end_lng  \
# ride_id
# 7E4A3A88DA791628         31090.0  38.870561 -77.044095  38.865553 -77.050030
# 9D05B4C81F3686B4         31247.0  38.879200 -76.995300  38.888553 -77.032427
# 0D0280428308DAD8         31613.0  38.869683 -77.010815  38.884095 -76.995234
# 76DA5E125917F688         31944.0  38.844015 -77.050537  38.845028 -77.051956
# BFEF6DFC09107A32         31802.0  38.879200 -76.995300  38.867373 -76.988039
#
#                  member_casual
# ride_id
# 7E4A3A88DA791628        member
# 9D05B4C81F3686B4        member
# 0D0280428308DAD8        casual
# 76DA5E125917F688        casual
# BFEF6DFC09107A32        casual

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 389656 entries, 7E4A3A88DA791628 to 1A2E9942B7490299
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   rideable_type       389656 non-null  object
#  1   started_at          389656 non-null  object
#  2   ended_at            389656 non-null  object
#  3   start_station_name  373687 non-null  object
#  4   start_station_id    373687 non-null  float64
#  5   end_station_name    371375 non-null  object
#  6   end_station_id      371375 non-null  float64
#  7   start_lat           389656 non-null  float64
#  8   start_lng           389656 non-null  float64
#  9   end_lat             388821 non-null  float64
#  10  end_lng             388821 non-null  float64
#  11  member_casual       389656 non-null  object
# dtypes: float64(6), object(6)
# memory usage: 38.6+ MB

# %%
df.describe()
# Out:
#        start_station_id  end_station_id      start_lat      start_lng  \
# count     373687.000000   371375.000000  389656.000000  389656.000000
# mean       31371.830711    31373.310829      38.901607     -77.031266
# std          257.141164      255.786904       0.027464       0.032933
# min        31000.000000    31000.000000      38.780000     -77.368416
# 25%        31213.000000    31216.000000      38.889867     -77.044400
# 50%        31277.000000    31276.000000      38.901755     -77.031617
# 75%        31608.000000    31609.000000      38.912652     -77.013667
# max        32901.000000    32901.000000      39.125828     -76.825535
#
#              end_lat        end_lng
# count  388821.000000  388821.000000
# mean       38.900539     -77.030933
# std         0.027154       0.032756
# min        38.710000     -77.368416
# 25%        38.888774     -77.044400
# 50%        38.900711     -77.030000
# 75%        38.911268     -77.012457
# max        39.125828     -76.825535

# %%
df['started_at']=pd.to_datetime(df['started_at'])
df['ended_at']=pd.to_datetime(df['ended_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 389656 entries, 7E4A3A88DA791628 to 1A2E9942B7490299
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   rideable_type       389656 non-null  object
#  1   started_at          389656 non-null  datetime64[ns]
#  2   ended_at            389656 non-null  datetime64[ns]
#  3   start_station_name  373687 non-null  object
#  4   start_station_id    373687 non-null  float64
#  5   end_station_name    371375 non-null  object
#  6   end_station_id      371375 non-null  float64
#  7   start_lat           389656 non-null  float64
#  8   start_lng           389656 non-null  float64
#  9   end_lat             388821 non-null  float64
#  10  end_lng             388821 non-null  float64
#  11  member_casual       389656 non-null  object
# dtypes: datetime64[ns](2), float64(6), object(4)
# memory usage: 38.6+ MB

# %%
df['no_of_days']=((df['ended_at']-df['started_at'])/np.timedelta64(1, 'D'))
df['no_of_days']=df['no_of_days'].astype(int)
df['no_of_days'].unique()
# Out:
# array([ 0,  5,  7,  1,  4,  3,  6,  2, 15,  8, 13, 16, 22, 20, 10, 25,  9,
#        11, 14, 36, 18, 19])

# %%
df['no_of_hours']=((df['ended_at']-df['started_at'])/np.timedelta64(1, 'h'))
df['no_of_hours']=df['no_of_hours'].astype(int)
df['no_of_hours'].unique()
# Out:
# array([  0,   1,   3,   2,  14,   4,  13,   6,   8, 128, 181,  24,  10,
#         21, 110,  95, 152,  16,   7, 109,  25,  28,   5,  12,  18,  45,
#         94,  68,  22,  17,  23,  59,  20,   9,  15,  77,  39,  11,  29,
#        381,  33,  69,  93, 214,  65,  48,  71, 105, 113, 121, 314, 141,
#         40,  19, 395, 545,  35, 498,  43, 199,  44, 240, 621,  98, 226,
#        157, 145, 114, 111, 256, 273, 142, 140,  27, 242,  62, 162, 182,
#         75,  42,  34, 255, 353, 163,  76,  32, 116, 877,  37, 377,  85,
#        433,  50,  36,  70, 164, 219,  67, 287,  52,  66, 100,  26, 120,
#        251, 144,  99, 211, 146,  31, 167, 244,  30,  47,  72, 473, 228,
#        280,  92, 129, 193, 150,  91, 260,  58,  51, 551])

# %%
df['no_of_min']=((df['ended_at']-df['started_at'])/np.timedelta64(1, 'm'))
df['no_of_min']=df['no_of_min'].astype(int)
df['no_of_min']
# Out:
# ride_id
# 7E4A3A88DA791628     3
# 9D05B4C81F3686B4    66
# 0D0280428308DAD8    23
# 76DA5E125917F688    71
# BFEF6DFC09107A32    64
#                     ..
# 6C11B71A0777CC14     7
# FD82268CBC0B38E4    16
# 5EADFDD3B5404390    11
# 59DD220CA7F189B5    37
# 1A2E9942B7490299     7
# Name: no_of_min, Length: 389656, dtype: int32

# %%
df
# Out:
#                   rideable_type          started_at            ended_at  \
# ride_id
# 7E4A3A88DA791628   classic_bike 2022-06-21 07:12:11 2022-06-21 07:15:20
# 9D05B4C81F3686B4   classic_bike 2022-06-29 15:01:20 2022-06-29 16:07:36
# 0D0280428308DAD8    docked_bike 2022-06-17 20:19:19 2022-06-17 20:42:48
# 76DA5E125917F688    docked_bike 2022-06-24 17:19:25 2022-06-24 18:30:43
# BFEF6DFC09107A32   classic_bike 2022-06-02 13:01:02 2022-06-02 14:05:56
# ...                         ...                 ...                 ...
# 6C11B71A0777CC14   classic_bike 2022-06-09 20:47:11 2022-06-09 20:54:18
# FD82268CBC0B38E4   classic_bike 2022-06-10 13:42:54 2022-06-10 13:59:11
# 5EADFDD3B5404390   classic_bike 2022-06-30 19:03:13 2022-06-30 19:14:56
# 59DD220CA7F189B5  electric_bike 2022-06-16 10:04:34 2022-06-16 10:41:47
# 1A2E9942B7490299   classic_bike 2022-06-19 14:45:33 2022-06-19 14:53:23
#
#                               start_station_name  start_station_id  \
# ride_id
# 7E4A3A88DA791628      Long Bridge Aquatic Center           31950.0
# 9D05B4C81F3686B4  8th & Eye St SE / Barracks Row           31608.0
# 0D0280428308DAD8        Potomac Ave & Half St SW           31648.0
# 76DA5E125917F688         Potomac Ave & 35th St S           31052.0
# BFEF6DFC09107A32  8th & Eye St SE / Barracks Row           31608.0
# ...                                          ...               ...
# 6C11B71A0777CC14             14th & Irving St NW           31124.0
# FD82268CBC0B38E4         North Capitol & R St NE           31527.0
# 5EADFDD3B5404390       New York Ave & 15th St NW           31222.0
# 59DD220CA7F189B5         Wilson Blvd & N Uhle St           31017.0
# 1A2E9942B7490299         North Capitol & R St NE           31527.0
#
#                                                    end_station_name  \
# ride_id
# 7E4A3A88DA791628       Long Bridge Park / Long Bridge Dr & 6th St S
# 9D05B4C81F3686B4                          Jefferson Dr & 14th St SW
# 0D0280428308DAD8  Eastern Market Metro / Pennsylvania Ave & 8th ...
# 76DA5E125917F688                               S Clark St & 33rd St
# BFEF6DFC09107A32                          Good Hope Rd & MLK Ave SE
# ...                                                             ...
# 6C11B71A0777CC14  Woodley Park Metro / Calvert St & Connecticut ...
# FD82268CBC0B38E4                                      8th & O St NW
# 5EADFDD3B5404390                                      8th & O St NW
# 59DD220CA7F189B5                    Columbia Pike & George Mason Dr
# 1A2E9942B7490299                                      8th & O St NW
#
#                   end_station_id  start_lat  start_lng    end_lat    end_lng  \
# ride_id
# 7E4A3A88DA791628         31090.0  38.870561 -77.044095  38.865553 -77.050030
# 9D05B4C81F3686B4         31247.0  38.879200 -76.995300  38.888553 -77.032427
# 0D0280428308DAD8         31613.0  38.869683 -77.010815  38.884095 -76.995234
# 76DA5E125917F688         31944.0  38.844015 -77.050537  38.845028 -77.051956
# BFEF6DFC09107A32         31802.0  38.879200 -76.995300  38.867373 -76.988039
# ...                          ...        ...        ...        ...        ...
# 6C11B71A0777CC14         31323.0  38.928552 -77.032224  38.923389 -77.051833
# FD82268CBC0B38E4         31281.0  38.912524 -77.008798  38.908640 -77.022770
# 5EADFDD3B5404390         31281.0  38.899032 -77.033354  38.908640 -77.022770
# 59DD220CA7F189B5         31923.0  38.891832 -77.084589  38.859306 -77.102019
# 1A2E9942B7490299         31281.0  38.912524 -77.008798  38.908640 -77.022770
#
#                  member_casual  no_of_days  no_of_hours  no_of_min
# ride_id
# 7E4A3A88DA791628        member           0            0          3
# 9D05B4C81F3686B4        member           0            1         66
# 0D0280428308DAD8        casual           0            0         23
# 76DA5E125917F688        casual           0            1         71
# BFEF6DFC09107A32        casual           0            1         64
# ...                        ...         ...          ...        ...
# 6C11B71A0777CC14        member           0            0          7
# FD82268CBC0B38E4        casual           0            0         16
# 5EADFDD3B5404390        casual           0            0         11
# 59DD220CA7F189B5        member           0            0         37
# 1A2E9942B7490299        casual           0            0          7
#
# [389656 rows x 15 columns]

# %%
df.isnull().sum()/len(df)*100
# Out:
# rideable_type         0.000000
# started_at            0.000000
# ended_at              0.000000
# start_station_name    4.098230
# start_station_id      4.098230
# end_station_name      4.691574
# end_station_id        4.691574
# start_lat             0.000000
# start_lng             0.000000
# end_lat               0.214292
# end_lng               0.214292
# member_casual         0.000000
# no_of_days            0.000000
# no_of_hours           0.000000
# no_of_min             0.000000
# dtype: float64

# %%
#Droping null Values with respect to End
df.dropna(inplace=True,subset=['end_lat','end_lng'],axis=0)
df.isnull().sum()/len(df)*100
# Out:
# rideable_type         0.000000
# started_at            0.000000
# ended_at              0.000000
# start_station_name    4.107031
# start_station_id      4.107031
# end_station_name      4.486898
# end_station_id        4.486898
# start_lat             0.000000
# start_lng             0.000000
# end_lat               0.000000
# end_lng               0.000000
# member_casual         0.000000
# no_of_days            0.000000
# no_of_hours           0.000000
# no_of_min             0.000000
# dtype: float64

# %% [markdown]
# ##Example for Distance
# coords_1 = (52.2296756, 21.0122287)
# coords_2 = (52.406374, 16.9251681)
# dist=distance.geodesic(coords_1, coords_2).km
# dist

# %%
# Defining a Function Distance_: 
def distance_(lat1,lng1,lat2,lng2):
    coords_1 =(lat1,lng1)
    coords_2 =(lat2,lng2)
    dist=distance.geodesic(coords_1, coords_2).km
    return dist

# %%
df['distance_in_km']=df.apply(lambda x:distance_(x.start_lat,x.start_lng,x.end_lat,x.end_lng),axis=1)
df['distance_in_km']
# Out:
# ride_id
# 7E4A3A88DA791628    0.757893
# 9D05B4C81F3686B4    3.384608
# 0D0280428308DAD8    2.094712
# 76DA5E125917F688    0.166801
# BFEF6DFC09107A32    1.456326
#                       ...
# 6C11B71A0777CC14    1.794427
# FD82268CBC0B38E4    1.286287
# 5EADFDD3B5404390    1.407302
# 59DD220CA7F189B5    3.914802
# 1A2E9942B7490299    1.286287
# Name: distance_in_km, Length: 388821, dtype: float64

# %%
df['distance_in_km']
# Out:
# ride_id
# 7E4A3A88DA791628    0.757893
# 9D05B4C81F3686B4    3.384608
# 0D0280428308DAD8    2.094712
# 76DA5E125917F688    0.166801
# BFEF6DFC09107A32    1.456326
#                       ...
# 6C11B71A0777CC14    1.794427
# FD82268CBC0B38E4    1.286287
# 5EADFDD3B5404390    1.407302
# 59DD220CA7F189B5    3.914802
# 1A2E9942B7490299    1.286287
# Name: distance_in_km, Length: 388821, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388821 entries, 7E4A3A88DA791628 to 1A2E9942B7490299
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   rideable_type       388821 non-null  object
#  1   started_at          388821 non-null  datetime64[ns]
#  2   ended_at            388821 non-null  datetime64[ns]
#  3   start_station_name  372852 non-null  object
#  4   start_station_id    372852 non-null  float64
#  5   end_station_name    371375 non-null  object
#  6   end_station_id      371375 non-null  float64
#  7   start_lat           388821 non-null  float64
#  8   start_lng           388821 non-null  float64
#  9   end_lat             388821 non-null  float64
#  10  end_lng             388821 non-null  float64
#  11  member_casual       388821 non-null  object
#  12  no_of_days          388821 non-null  int32
#  13  no_of_hours         388821 non-null  int32
#  14  no_of_min           388821 non-null  int32
#  15  distance_in_km      388821 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int32(3), object(4)
# memory usage: 54.0+ MB

# %%
#Seperating Numerical and Categotrical Columns
Numerical=df.select_dtypes(['int32','float64']).columns.tolist()
Categorical=df.select_dtypes(['object']).columns.tolist()

# %%
print(Numerical,Categorical)
# Out:
# ['start_station_id', 'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'no_of_days', 'no_of_hours', 'no_of_min', 'distance_in_km'] ['rideable_type', 'start_station_name', 'end_station_name', 'member_casual']

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Categotrical

# %%
def UVA_category(data,cat_group):
    '''
    Univariate_Analysis_categorical
    takes a group of variables (category) and plot/print all the value_counts and barplot.
    '''
    # setting figure_size
    size = len(cat_group)
    plt.figure(figsize = (8*size,5), dpi = 100)

    # for every variable
    for j,i in enumerate(cat_group):
        norm_count = data[i].value_counts(normalize = True)
        n_uni = data[i].nunique()
  
        #Plotting the variable with every information
        plt.subplot(1,size,j+1)
        sns.barplot(norm_count.index ,norm_count, order = norm_count.index)
        plt.xlabel('{}'.format(i), fontsize = 20)
        plt.ylabel('fraction/percent', fontsize = 20)
        plt.title('Distribution of {}'.format(i))

# %%
for i in range(0,len(Categorical),1):
    UVA_category(df,Categorical[i:i+1])

# %% [markdown]
# ### Numerical

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.describe().T
# Out:
#                      count     mean    std      min      25%      50%  \
# start_station_id 372852.00 31371.65 256.87 31000.00 31213.00 31277.00
# end_station_id   371375.00 31373.31 255.79 31000.00 31216.00 31276.00
# start_lat        388821.00    38.90   0.03    38.78    38.89    38.90
# start_lng        388821.00   -77.03   0.03   -77.37   -77.04   -77.03
# end_lat          388821.00    38.90   0.03    38.71    38.89    38.90
# end_lng          388821.00   -77.03   0.03   -77.37   -77.04   -77.03
# no_of_days       388821.00     0.00   0.12     0.00     0.00     0.00
# no_of_hours      388821.00     0.13   3.13     0.00     0.00     0.00
# no_of_min        388821.00    22.95 188.67   -31.00     7.00    12.00
# distance_in_km   388821.00     1.91   1.52     0.00     0.91     1.59
#
#                       75%      max
# start_station_id 31608.00 32901.00
# end_station_id   31609.00 32901.00
# start_lat           38.91    39.13
# start_lng          -77.01   -76.83
# end_lat             38.91    39.13
# end_lng            -77.01   -76.83
# no_of_days           0.00    36.00
# no_of_hours          0.00   877.00
# no_of_min           22.00 52656.00
# distance_in_km       2.56    28.18

# %%
# No of Record showing negitive Time 
print(len(df[df['no_of_min']<0]))
# Out:
# 5

# %%
# Droping those 5 Rows since those might be Miss entry
# or it might be potentially false starts or users trying to re-dock a bike to ensure it's secure
df.drop(index=df[df['no_of_min']<0].index,axis=0)
# 59DD220CA7F189B5        31923.00      38.89     -77.08    38.86   -77.10
# 1A2E9942B7490299        31281.00      38.91     -77.01    38.91   -77.02
#
#                  member_casual  no_of_days  no_of_hours  no_of_min  \
# ride_id
# 7E4A3A88DA791628        member           0            0          3
# 9D05B4C81F3686B4        member           0            1         66
# 0D0280428308DAD8        casual           0            0         23
# 76DA5E125917F688        casual           0            1         71
# BFEF6DFC09107A32        casual           0            1         64
# ...                        ...         ...          ...        ...
# 6C11B71A0777CC14        member           0            0          7
# FD82268CBC0B38E4        casual           0            0         16
# 5EADFDD3B5404390        casual           0            0         11
# 59DD220CA7F189B5        member           0            0         37
# 1A2E9942B7490299        casual           0            0          7
#
#                   distance_in_km
# ride_id
# 7E4A3A88DA791628            0.76
# 9D05B4C81F3686B4            3.38
# 0D0280428308DAD8            2.09
# 76DA5E125917F688            0.17
# BFEF6DFC09107A32            1.46
# ...                          ...
# 6C11B71A0777CC14            1.79
# FD82268CBC0B38E4            1.29
# 5EADFDD3B5404390            1.41
# 59DD220CA7F189B5            3.91
# 1A2E9942B7490299            1.29
#
# [388816 rows x 16 columns]

# %%
def UAEnumerical(data,cont_group):
    '''
    Univariate_Analysis_Numerical
    takes a group of variables (Continous) and plot/print all the value_counts and barplot.
    '''
    size=len(cont_group)
    plt.figure(figsize=(7*size,3),dpi=100)
    #looping for each variable
 
    for i,j in enumerate(cont_group):
        # calculating descriptives of variable
        _min=data[j].min()
        _max=data[j].max()
        _range=data[j].max()-data[j].min()
        mean=data[j].mean()
        median=data[j].median()
        stddev=data[j].std()
        
        # calculating points of standard deviation
        points = mean-stddev, mean+stddev
        
        #Plotting the variable with every information   
        plt.subplot(1,size,i+1)
        sns.kdeplot(data[j],color='orange',shade=True,bw=0.5)
        sns.lineplot(x=points,y=[0,0],color = 'black',label="std_dev")
        sns.scatterplot([_min,_max],[0,0],color='green',label="Min-Max",sizes=5)
        sns.scatterplot([mean], [0],color='red', label = "mean",sizes=5)
        sns.scatterplot([median],[0], color='yellow', label = "median",sizes=5)
        plt.xlabel('{}'.format(j), fontsize = 10)
        plt.ylabel('Density')
        plt.title('std_dev = {}; range = {}\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),
                                                                                                       (round(_min,2),round(_max,2),round(_range,2)),
                                                                                                       round(mean,2),
                                                                                                       round(median,2)))

# %%
for i in range(0,len(Numerical),2):
    UAEnumerical(df,Numerical[i:i+2])

# %% [markdown]
# ## Bivariate Analysis : Numerical-Numerical

# %% [markdown]
# #### With help of Correlation

# %%
numerical_col = df[Numerical]
numerical_col.dropna().corr()
# Out:
#                   start_station_id  end_station_id  start_lat  start_lng  \
# start_station_id              1.00            0.49       0.04       0.16
# end_station_id                0.49            1.00       0.05       0.07
# start_lat                     0.04            0.05       1.00      -0.08
# start_lng                     0.16            0.07      -0.08       1.00
# end_lat                       0.07            0.04       0.83      -0.06
# end_lng                       0.07            0.17      -0.07       0.83
# no_of_days                    0.01            0.02      -0.01      -0.00
# no_of_hours                   0.01            0.02      -0.01      -0.01
# no_of_min                     0.01            0.02      -0.02      -0.01
# distance_in_km                0.02            0.02       0.05      -0.03
#
#                   end_lat  end_lng  no_of_days  no_of_hours  no_of_min  \
# start_station_id     0.07     0.07        0.01         0.01       0.01
# end_station_id       0.04     0.17        0.02         0.02       0.02
# start_lat            0.83    -0.07       -0.01        -0.01      -0.02
# start_lng           -0.06     0.83       -0.00        -0.01      -0.01
# end_lat              1.00    -0.08        0.00        -0.00      -0.01
# end_lng             -0.08     1.00        0.00        -0.00      -0.01
# no_of_days           0.00     0.00        1.00         0.97       0.97
# no_of_hours         -0.00    -0.00        0.97         1.00       1.00
# no_of_min           -0.01    -0.01        0.97         1.00       1.00
# distance_in_km      -0.02    -0.00        0.02         0.02       0.04
#
#                   distance_in_km
# start_station_id            0.02
# end_station_id              0.02
# start_lat                   0.05
# start_lng                  -0.03
# end_lat                    -0.02
# end_lng                    -0.00
# no_of_days                  0.02
# no_of_hours                 0.02
# no_of_min                   0.04
# distance_in_km              1.00

# %%
for_method=['pearson','kendall','spearman']
# plotting heatmap usill all methods for all numerical variables
for i in for_method:
    plt.figure(figsize=(10,7), dpi=100)
    correlation = numerical_col.dropna().corr(method=i)
    sns.heatmap(correlation, linewidth = 1,annot=True)
    plt.title(i, fontsize=18)
    plt.show()

# %%
##Checking for outliers
for i in Numerical:
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# ## Bivariante Analysis: Categorical to Numerical

# %%
def NC_plot(Target,Numeric):
    sns.boxplot(x=Target,y=Numeric, color='b', orient='v')
    plt.show()
for i in Numerical:
    NC_plot(df['member_casual'],df[i])

# %% [markdown]
# ## Bivariate Analysis : Categorical-Categorical

# %%
#Check the frequency count between th TARGET and other features
pd.crosstab(df['member_casual'],df['rideable_type'],normalize=True)*100
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# member_casual
# casual                31.20         7.63           7.05
# member                45.72         0.00           8.40

# %%
pd.crosstab(df['member_casual'],df['start_station_name'],normalize=True)*100
# Out:
# start_station_name  10th & E St NW  10th & Florida Ave NW  10th & G St NW  \
# member_casual
# casual                        0.22                   0.10            0.15
# member                        0.18                   0.27            0.16
#
# start_station_name  10th & H St NE  10th & K St NW  10th & Monroe St NE  \
# member_casual
# casual                        0.09            0.22                 0.06
# member                        0.12            0.24                 0.07
#
# start_station_name  10th & U St NW  10th St & Constitution Ave NW  \
# member_casual
# casual                        0.08                           0.29
# member                        0.15                           0.13
#
# start_station_name  10th St & L'Enfant Plaza SW  11th & C St SE  ...  \
# member_casual                                                    ...
# casual                                     0.26            0.07  ...
# member                                     0.06            0.14  ...
#
# start_station_name  Wilson Blvd. & N. Vermont St.  Windham Ln & Amherst Ave  \
# member_casual
# casual                                       0.01                      0.01
# member                                       0.02                      0.00
#
# start_station_name  Wisconsin Ave & Brandywine St NW  \
# member_casual
# casual                                          0.02
# member                                          0.06
#
# start_station_name  Wisconsin Ave & Ingomar St NW  \
# member_casual
# casual                                       0.01
# member                                       0.03
#
# start_station_name  Wisconsin Ave & Newark St NW  Wisconsin Ave & O St NW  \
# member_casual
# casual                                      0.06                     0.14
# member                                      0.07                     0.17
#
# start_station_name  Woodglen Dr & Executive Blvd  \
# member_casual
# casual                                      0.01
# member                                      0.01
#
# start_station_name  Woodley Park Metro / Calvert St & Connecticut Ave NW  \
# member_casual
# casual                                                           0.15
# member                                                           0.19
#
# start_station_name  Woodmont Ave & Strathmore St  Yuma St & Tenley Circle NW
# member_casual
# casual                                      0.03                        0.02
# member                                      0.04                        0.04
#
# [2 rows x 687 columns]

# %%
pd.crosstab(df['member_casual'],df['end_station_name'],normalize=True)*100
# Out:
# end_station_name  10th & E St NW  10th & Florida Ave NW  10th & G St NW  \
# member_casual
# casual                      0.25                   0.11            0.17
# member                      0.20                   0.27            0.21
#
# end_station_name  10th & H St NE  10th & K St NW  10th & Monroe St NE  \
# member_casual
# casual                      0.09            0.25                 0.04
# member                      0.13            0.23                 0.06
#
# end_station_name  10th & U St NW  10th St & Constitution Ave NW  \
# member_casual
# casual                      0.09                           0.33
# member                      0.14                           0.17
#
# end_station_name  10th St & L'Enfant Plaza SW  11th & C St SE  ...  \
# member_casual                                                  ...
# casual                                   0.23            0.06  ...
# member                                   0.10            0.15  ...
#
# end_station_name  Wilson Blvd. & N. Vermont St.  Windham Ln & Amherst Ave  \
# member_casual
# casual                                     0.02                      0.01
# member                                     0.02                      0.00
#
# end_station_name  Wisconsin Ave & Brandywine St NW  \
# member_casual
# casual                                        0.01
# member                                        0.03
#
# end_station_name  Wisconsin Ave & Ingomar St NW  Wisconsin Ave & Newark St NW  \
# member_casual
# casual                                     0.01                          0.05
# member                                     0.01                          0.07
#
# end_station_name  Wisconsin Ave & O St NW  Woodglen Dr & Executive Blvd  \
# member_casual
# casual                               0.18                          0.01
# member                               0.16                          0.01
#
# end_station_name  Woodley Park Metro / Calvert St & Connecticut Ave NW  \
# member_casual
# casual                                                         0.10
# member                                                         0.14
#
# end_station_name  Woodmont Ave & Strathmore St  Yuma St & Tenley Circle NW
# member_casual
# casual                                    0.03                        0.00
# member                                    0.04                        0.02
#
# [2 rows x 688 columns]

# %% [markdown]
# #### Outlier Treatement

# %%
def change_outlier(data, col_group,threshold=2):
    for i in col_group:

        q1= data[i].quantile(0.25)
        q3= data[i].quantile(0.75)
        IQR = q3 - q1
        whis_low = q1-(threshold*IQR)
        whis_high = q3+(threshold*IQR)
        data[i][data[i]>whis_high] = whis_high
        data[i][data[i]<whis_low] = whis_low

# %%
## Treating outlier 
change_outlier(df,['no_of_days','no_of_hours','no_of_min', 'distance_in_km'],threshold=3)

# %%
for i in range(0,len(Numerical),2):
    UAEnumerical(df,Numerical[i:i+2])

# %%
df.columns
# Out:
# Index(['rideable_type', 'started_at', 'ended_at', 'start_station_name',
#        'start_station_id', 'end_station_name', 'end_station_id', 'start_lat',
#        'start_lng', 'end_lat', 'end_lng', 'member_casual', 'no_of_days',
#        'no_of_hours', 'no_of_min', 'distance_in_km'],
#       dtype='object')

# %%
df1=df.drop(columns=['started_at', 'ended_at', 'start_station_name','end_station_name','start_lat',
       'start_lng', 'end_lat', 'end_lng','no_of_days','no_of_hours'],axis=1).reset_index(drop=True)
df1
# Out:
#         rideable_type  start_station_id  end_station_id member_casual  \
# 0        classic_bike          31950.00        31090.00        member
# 1        classic_bike          31608.00        31247.00        member
# 2         docked_bike          31648.00        31613.00        casual
# 3         docked_bike          31052.00        31944.00        casual
# 4        classic_bike          31608.00        31802.00        casual
# ...               ...               ...             ...           ...
# 388816   classic_bike          31124.00        31323.00        member
# 388817   classic_bike          31527.00        31281.00        casual
# 388818   classic_bike          31222.00        31281.00        casual
# 388819  electric_bike          31017.00        31923.00        member
# 388820   classic_bike          31527.00        31281.00        casual
#
#         no_of_min  distance_in_km
# 0               3            0.76
# 1              66            3.38
# 2              23            2.09
# 3              67            0.17
# 4              64            1.46
# ...           ...             ...
# 388816          7            1.79
# 388817         16            1.29
# 388818         11            1.41
# 388819         37            3.91
# 388820          7            1.29
#
# [388821 rows x 6 columns]

# %%
df1=pd.get_dummies(df1,drop_first=True)
df1['Is_member']=df1['member_casual_member']
df1.drop(columns='member_casual_member',inplace=True)

# %%
df1
# Out:
#         start_station_id  end_station_id  no_of_min  distance_in_km  \
# 0               31950.00        31090.00          3            0.76
# 1               31608.00        31247.00         66            3.38
# 2               31648.00        31613.00         23            2.09
# 3               31052.00        31944.00         67            0.17
# 4               31608.00        31802.00         64            1.46
# ...                  ...             ...        ...             ...
# 388816          31124.00        31323.00          7            1.79
# 388817          31527.00        31281.00         16            1.29
# 388818          31222.00        31281.00         11            1.41
# 388819          31017.00        31923.00         37            3.91
# 388820          31527.00        31281.00          7            1.29
#
#         rideable_type_docked_bike  rideable_type_electric_bike  Is_member
# 0                               0                            0          1
# 1                               0                            0          1
# 2                               1                            0          0
# 3                               1                            0          0
# 4                               0                            0          0
# ...                           ...                          ...        ...
# 388816                          0                            0          1
# 388817                          0                            0          0
# 388818                          0                            0          0
# 388819                          0                            1          1
# 388820                          0                            0          0
#
# [388821 rows x 7 columns]

# %%
df1.corr()
# Out:
#                              start_station_id  end_station_id  no_of_min  \
# start_station_id                         1.00            0.49      -0.01
# end_station_id                           0.49            1.00      -0.01
# no_of_min                               -0.01           -0.01       1.00
# distance_in_km                           0.01            0.02       0.33
# rideable_type_docked_bike               -0.03           -0.03       0.33
# rideable_type_electric_bike              0.02            0.02      -0.08
# Is_member                               -0.00            0.00      -0.34
#
#                              distance_in_km  rideable_type_docked_bike  \
# start_station_id                       0.01                      -0.03
# end_station_id                         0.02                      -0.03
# no_of_min                              0.33                       0.33
# distance_in_km                         1.00                      -0.04
# rideable_type_docked_bike             -0.04                       1.00
# rideable_type_electric_bike            0.13                      -0.12
# Is_member                             -0.02                      -0.31
#
#                              rideable_type_electric_bike  Is_member
# start_station_id                                    0.02      -0.00
# end_station_id                                      0.02       0.00
# no_of_min                                          -0.08      -0.34
# distance_in_km                                      0.13      -0.02
# rideable_type_docked_bike                          -0.12      -0.31
# rideable_type_electric_bike                         1.00       0.00
# Is_member                                           0.00       1.00

# %%
#heat map 
plt.figure(figsize=(8,5),dpi=100)
sns.heatmap(df1.corr(),linewidths=1,linecolor='black',annot=True)
# Out:
# <AxesSubplot:>

# %%
df1.isnull().sum()
# Out:
# start_station_id               15969
# end_station_id                 17446
# no_of_min                          0
# distance_in_km                     0
# rideable_type_docked_bike          0
# rideable_type_electric_bike        0
# Is_member                          0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388821 entries, 0 to 388820
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   start_station_id             372852 non-null  float64
#  1   end_station_id               371375 non-null  float64
#  2   no_of_min                    388821 non-null  int32
#  3   distance_in_km               388821 non-null  float64
#  4   rideable_type_docked_bike    388821 non-null  uint8
#  5   rideable_type_electric_bike  388821 non-null  uint8
#  6   Is_member                    388821 non-null  uint8
# dtypes: float64(3), int32(1), uint8(3)
# memory usage: 11.5 MB

# %%
df1['start_station_id']=df1['start_station_id'].astype('object')
df1['end_station_id']=df1['end_station_id'].astype('object')

# %%
df1['start_station_id']=df1['start_station_id'].fillna(df1['start_station_id'].max())
df1['end_station_id']=df1['end_station_id'].fillna(df1['end_station_id'].max())

# %%
df1.isnull().sum()
# Out:
# start_station_id               0
# end_station_id                 0
# no_of_min                      0
# distance_in_km                 0
# rideable_type_docked_bike      0
# rideable_type_electric_bike    0
# Is_member                      0
# dtype: int64

# %%
df1['start_station_id']=df1['start_station_id'].astype('float64')
df1['end_station_id']=df1['end_station_id'].astype('float64')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388821 entries, 0 to 388820
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   start_station_id             388821 non-null  float64
#  1   end_station_id               388821 non-null  float64
#  2   no_of_min                    388821 non-null  int32
#  3   distance_in_km               388821 non-null  float64
#  4   rideable_type_docked_bike    388821 non-null  uint8
#  5   rideable_type_electric_bike  388821 non-null  uint8
#  6   Is_member                    388821 non-null  uint8
# dtypes: float64(3), int32(1), uint8(3)
# memory usage: 11.5 MB

# %% [markdown]
# ## Model building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,f1_score

# %%
X = df1.drop(columns=['Is_member'])
Y = df1.Is_member

# %%
# Spliting Data
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=.25,shuffle=True,stratify=Y,random_state=23)

# %%
#Creating the LogisticRegression object
lg_model = LogisticRegression(random_state=23)

# %%
lg_model.fit(xtrain,ytrain)
# Out:
# LogisticRegression(random_state=23)

# %%
p1_ytrain=lg_model.predict(xtrain)

# %%
accuracy_score(ytrain,p1_ytrain),f1_score(ytrain,p1_ytrain)
# Out:
# (0.6451862901428252, 0.7181856065455001)

# %%
p1_ytest=lg_model.predict(xtest)

# %%
accuracy_score(ytest,p1_ytest),f1_score(ytest,p1_ytest)
# Out:
# (0.6466679011583647, 0.7199491202035193)

# %%
print(classification_report(ytrain,p1_ytrain),classification_report(ytest,p1_ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.42      0.52    133778
#            1       0.63      0.84      0.72    157837
#
#     accuracy                           0.65    291615
#    macro avg       0.66      0.63      0.62    291615
# weighted avg       0.65      0.65      0.63    291615
#                precision    recall  f1-score   support
#
#            0       0.69      0.42      0.52     44593
#            1       0.63      0.84      0.72     52613
#
#     accuracy                           0.65     97206
#    macro avg       0.66      0.63      0.62     97206
# weighted avg       0.66      0.65      0.63     97206

# %% [markdown]
# # Random Forest Algorithm

# %%
#creting RandomForestClassifier Object
rfc_model=RandomForestClassifier(random_state=23)

# %%
rfc_model.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(random_state=23)

# %%
#predicting with seen Data
p2_ytrain=rfc_model.predict(xtrain)

# %%
accuracy_score(ytrain,p2_ytrain),f1_score(ytrain,p2_ytrain)
# Out:
# (0.9328601066474632, 0.9390921845495298)

# %%
#predicting with Unseen Data
p2_ytest=rfc_model.predict(xtest)

# %%
accuracy_score(ytest,p2_ytest),f1_score(ytest,p2_ytest)
# Out:
# (0.7121679731703804, 0.7433990296871705)

# %%
print(classification_report(ytrain,p2_ytrain),classification_report(ytest,p2_ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93    133778
#            1       0.92      0.96      0.94    157837
#
#     accuracy                           0.93    291615
#    macro avg       0.93      0.93      0.93    291615
# weighted avg       0.93      0.93      0.93    291615
#                precision    recall  f1-score   support
#
#            0       0.70      0.64      0.67     44593
#            1       0.72      0.77      0.74     52613
#
#     accuracy                           0.71     97206
#    macro avg       0.71      0.71      0.71     97206
# weighted avg       0.71      0.71      0.71     97206

# %% [markdown]
# # GradientBoostingClassifier

# %%
#Creating a object of GradientBoostingClassifier
gdc_model=GradientBoostingClassifier(random_state=23)

# %%
gdc_model.fit(xtrain,ytrain)
# Out:
# GradientBoostingClassifier(random_state=23)

# %%
p3_ytrain=gdc_model.predict(xtrain)

# %%
accuracy_score(ytrain,p3_ytrain),f1_score(ytrain,p3_ytrain)
# Out:
# (0.6952591601940915, 0.7541123313217842)

# %%
#predicting with Unseen Data
p3_ytest=gdc_model.predict(xtest)

# %%
accuracy_score(ytest,p3_ytest),f1_score(ytest,p3_ytest)
# Out:
# (0.6963870542970598, 0.7551580816167383)

# %%
print(classification_report(ytrain,p3_ytrain),classification_report(ytest,p3_ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.50      0.60    133778
#            1       0.67      0.86      0.75    157837
#
#     accuracy                           0.70    291615
#    macro avg       0.71      0.68      0.68    291615
# weighted avg       0.71      0.70      0.68    291615
#                precision    recall  f1-score   support
#
#            0       0.76      0.50      0.60     44593
#            1       0.67      0.87      0.76     52613
#
#     accuracy                           0.70     97206
#    macro avg       0.71      0.68      0.68     97206
# weighted avg       0.71      0.70      0.68     97206

# %% [markdown]
# ## Hyperparater tunning of Random Forest

# %% [markdown]
# rf_params = {
#     'max_depth': [15,20,30,50,80],
#     'min_samples_leaf': [1,2,4,8,10],
#     "bootstrap":[True,False],
#     "criterion":['gini','entropy']
# }

# %% [markdown]
# clf = rfc_model
# rfc_grid = GridSearchCV(clf, rf_params, cv=3, scoring='f1',n_jobs=-1)
# rfc_grid.fit(xtrain,ytrain)

# %% [markdown]
# print(rfc_grid.best_params_)
# print("Accuracy:"+ str(rfc_grid.best_score_))

# %%
rfc_grid =RandomForestClassifier(bootstrap= True, criterion= 'entropy', max_depth= 20, min_samples_leaf= 1,random_state=23,n_jobs=-1)
rfc_grid.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=20, n_jobs=-1,
#                        random_state=23)

# %% [markdown]
# #### {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1}
# Accuracy:0.7624801689751607

# %%
p_ytrain=rfc_grid.predict(xtrain)

# %%
accuracy_score(ytrain,p_ytrain),f1_score(ytrain,p_ytrain)
# Out:
# (0.83277952094371, 0.8601139421339192)

# %%
p_ytest=rfc_grid.predict(xtest)

# %%
accuracy_score(ytest,p_ytest),f1_score(ytest,p_ytest)
# Out:
# (0.7201098697611259, 0.7669855516824966)

# %%
print(classification_report(ytrain,p_ytrain),classification_report(ytest,p_ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79    133778
#            1       0.79      0.95      0.86    157837
#
#     accuracy                           0.83    291615
#    macro avg       0.85      0.82      0.83    291615
# weighted avg       0.85      0.83      0.83    291615
#                precision    recall  f1-score   support
#
#            0       0.76      0.57      0.65     44593
#            1       0.70      0.85      0.77     52613
#
#     accuracy                           0.72     97206
#    macro avg       0.73      0.71      0.71     97206
# weighted avg       0.73      0.72      0.71     97206
